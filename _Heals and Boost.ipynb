# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_csv('/Users/User/Desktop/PUBG_match_data.csv')

# %%
dataset[['boosts', 'heals']].describe()
# Out:
#              boosts         heals
# count  4.446966e+06  4.446966e+06
# mean   1.106908e+00  1.370147e+00
# std    1.715794e+00  2.679982e+00
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    2.000000e+00  2.000000e+00
# max    3.300000e+01  8.000000e+01

# %%
print('Average number of heals used is {: .1f}, 99% of player used {: .1f} heals or less, the max number of heals used was {: .1f}' .format(dataset['heals'].mean(), dataset['heals'].quantile(0.99), dataset['heals'].max()))

print('')

print('Average number of boosts used is {: .1f}, 99% of player used {: .1f} boosts or less, the max number of boosts used was {: .1f}' .format(dataset['boosts'].mean(), dataset['boosts'].quantile(0.99), dataset['boosts'].max()))
# Out:
# Average number of heals used is  1.4, 99% of player used  12.0 heals or less, the max number of heals used was  80.0
#
# Average number of boosts used is  1.1, 99% of player used  7.0 boosts or less, the max number of boosts used was  33.0

# %%
tmp_df= dataset.copy()
plt.figure(figsize = (40,18))
sns.pointplot(x = 'heals', y = 'winPlacePerc', data=tmp_df, color = 'blue', alpha = 1.0)
sns.pointplot(x = 'boosts', y = 'winPlacePerc', data=tmp_df, color = 'lime', alpha = 1.0)
plt.xlabel('Number of Boosts/Heals Used', fontsize = 20, color = 'blue')
plt.ylabel('WinPlacePerc', fontsize = 20, color = 'blue')
plt.text(4, 0.9, 'Heals', color = 'lime', fontsize = 20)
plt.text(4, 0.6, 'Boosts', color = 'blue', fontsize = 20)
plt.title('Heals vs Boosts affecting winPlacePerc', color = 'blue', fontsize = 20)
plt.grid()

# %%
plt.figure(figsize=(40, 20))
sns.jointplot(x = 'winPlacePerc', y = 'heals', data = dataset, height = 10, ratio = 3)
plt.ticklabel_format(style='plain',axis = 'both')
plt.show()
plt.figure(figsize=(40, 20))
sns.jointplot(x = 'winPlacePerc', y = 'boosts', data = dataset, height = 10, ratio = 3)
plt.ticklabel_format(style='plain',axis = 'both')
plt.show()
